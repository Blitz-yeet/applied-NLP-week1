# %% [markdown]
# # 2) Adverbs: Do Great Writers Avoid Them?
#
# **Goal:** Estimate -ly adverb rate and compare across the two texts.

# %% [markdown]
# # Setup: Load Texts
#
# This notebook needs **Pet Semetary** and **The Shining** as input texts.
#
# **How to provide the texts:**
# 1. Download books from Project Gutenberg (IDs 11 and 12) as txts. [go to https://www.gutenberg.org/ebooks/11 and https://www.gutenberg.org/ebooks/12]
#
# 2. Place two text files in the "data" folder with names:
#    - `PetSemetary.txt`  (PetSemetary)
#    - `TheShining.txt` (TheShining)

# %%
import re
from pathlib import Path

# %%
def load_texts(local_PetSemetary: str = '../data/PetSemetary.txt',
               local_TheShining: str = '../data/TheShining.txt'):
    """Load PetSemetary and TheShining texts from disk.

    Parameters
    ----------
    local_PetSemetary : str
        Path to PetSemetaryy text file. Defaults to '../data/PetSemetary.txt'.
    local_TheShining : str
        Path to TheShining text file. Defaults to '../data/TheShining.txt'.

    Returns
    -------
    tuple[str, str]
        (PetSemetary_text, TheShining_text).

    Raises
    ------
    FileNotFoundError
        If either file is missing.

    Extra Notes
    -----------
    - Using UTF-8 with `errors='ignore'` avoids codec exceptions on
      older Project Gutenberg dumps or inconsistent encodings.
    """
    p1, p2 = Path(local_PetSemetary), Path(local_TheShining)

    # Fail fast with a clear message if a file is missing
    if not p1.exists():
        raise FileNotFoundError(
            f"Missing file: {p1}\n"
            "→ Please place 'PetSemetary.txt' at this path or update load_texts(...)."
        )
    if not p2.exists():
        raise FileNotFoundError(
            f"Missing file: {p2}\n"
            "→ Please place 'TheShining.txt' at this path or update load_texts(...)."
        )

    # Read the files (UTF-8; ignore undecodable bytes to stay robust)
    PetSemetaryy   = p1.read_text(encoding='utf-8', errors='ignore')
    TheShining = p2.read_text(encoding='utf-8', errors='ignore')
    return PetSemetaryy, TheShining

def normalize(text: str) -> str:
    """Normalize a Gutenberg-like text for tokenization.

    Steps
    -----
    1) Heuristically strip Project Gutenberg headers/footers if present
       (looks for *** START ... *** END markers).
    2) Normalize newlines to '\n'.

    Parameters
    ----------
    text : str
        Raw text as loaded from disk (can be empty).

    Returns
    -------
    str
        Cleaned text suitable for tokenization and counting.
    """
    if not text:
        return ''
    # Clip to the main body if markers are present.
    start = text.find('*** START')
    end   = text.find('*** END')
    if start != -1 and end != -1 and end > start:
        text = text[start:end]
    # Normalize Windows line endings.
    return text.replace('\r\n', '\n')

# Load raw texts (forgiving: returns '' if a file is missing)
PetSemetary_raw, TheShining_raw = load_texts()

# Normalize for tokenization
PetSemetary   = normalize(PetSemetary_raw)
TheShining = normalize(TheShining_raw)

print(f"PetSemetary chars: {len(PetSemetary):,} | TheShining chars: {len(TheShining):,}")
# Out:
# PetSemetary chars: 812,517 | TheShining chars: 906,176

# %% [markdown]
# ### Helpers: Tokenization

# %%
WORD_RE = re.compile(r"[A-Za-z']+")  # keep apostrophes in words (e.g., don't -> don't)

def words(text: str):
    """Simple word tokenizer (lowercased, ASCII letters + apostrophes).

    Pros
    ----
    - Very fast and dependency-free.
    - Good enough for frequency/keyness demonstrations.

    Cons
    ----
    - No punctuation words, no sentence boundaries, no POS tags.
    - May treat possessives inconsistently across sources.

    Returns
    -------
    list[str]
        Lowercased word words.
    """
    return WORD_RE.findall(text.lower())


def sentences(text: str):
    """Naive sentence splitter using punctuation boundaries.

    Uses a regex to split on '.', '!', '?' followed by whitespace.
    Because this is heuristic, treat results as approximate.

    Returns
    -------
    list[str]
        Sentence-like strings.
    """
    return [s.strip() for s in re.split(r'(?<=[.!?])\s+', text) if s.strip()]



PetSemetary_words = words(PetSemetary)
TheShining_words = words(TheShining)

PetSemetary_sentences = sentences(PetSemetary)
TheShiningentences = sentences(TheShining)

print(f"PetSemetary words: {len(PetSemetary_words):,} | TheShining words: {len(TheShining):,}")
print(f"PetSemetary sentences: {len(PetSemetary_sentences):,} | Looking TheShining sentences: {len(TheShiningentences):,}")
# Out:
# PetSemetary words: 150,508 | TheShining words: 906,176
# PetSemetary sentences: 9,269 | Looking TheShining sentences: 12,914

# %% [markdown]
# ### Estimate -ly Adverb Rate

# %%
def adverb_rate(words):
    adverbs = [w for w in words if w.endswith('ly') and len(w)>2]
    return len(adverbs), len(words), (len(adverbs)/len(words))*100

a_adv, a_total, a_pct = adverb_rate(PetSemetary_words)
g_adv, g_total, g_pct = adverb_rate(TheShining_words)
print(f"PetSemetaryy: {a_adv}/{a_total} = {a_pct:.2f}%")
print(f"Looking TheShining: {g_adv}/{g_total} = {g_pct:.2f}%")
# Out:
# PetSemetaryy: 2261/150508 = 1.50%
# Looking TheShining: 2355/162197 = 1.45%

# %% [markdown]
# **Prompt:** Inspect a sample of detected -ly words. Which are true adverbs vs. adjectives/nouns? How would you refine the rule?

# %%
# Show some adverbs from PetSemetary
adverbs_PetSemetary = [w for w in PetSemetary_words if w.endswith('ly') and len(w)>2]
print(f"PetSemetary adverbs (first 20): {adverbs_PetSemetary[:20]}")
# Out:
# PetSemetary adverbs (first 20): ['purely', 'frequently', 'easily', 'probably', 'finally', 'certainly', 'simply', 'only', 'early', 'only', 'only', 'entirely', 'really', 'simply', 'only', 'early', 'completely', 'only', 'early', 'particularly']

# %% [markdown]
# Let's use a smarter way to find adverbs:

# %%
# Run this cell once
import spacy
from spacy.cli import download

try:
    nlp = spacy.load("en_core_web_sm")
except OSError:
    download("en_core_web_sm")          # downloads the small English model
    nlp = spacy.load("en_core_web_sm")  # try again
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
def strip_gutenberg_markup(t: str) -> str:
    # remove lone underscores and _italic_ markup
    t = re.sub(r"\b_+\b", " ", t)
    t = re.sub(r"_([A-Za-z]+)_", r"\1", t)
    return t

# 1) Pre-clean, then parse
text_clean = strip_gutenberg_markup(PetSemetary)  # or your variable
doc = nlp(text_clean)

true_adverbs = [t.text for t in doc if t.pos_ == "ADV"]
true_adverbs[:20]
# Out:
# ['purely',
#  'frequently',
#  'most',
#  'ever',
#  'easily',
#  'most',
#  'probably',
#  'away',
#  'finally',
#  'too',
#  'far',
#  'certainly',
#  'too',
#  'far',
#  'simply',
#  'before',
#  'also',
#  'later',
#  'about',
#  'very']
